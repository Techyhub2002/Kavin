# %% [markdown]
# <a href="https://www.kaggle.com/code/kavin2002/movie-collections?scriptVersionId=94731477" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
MENU_PROMPT= "\n Enter 'a' to add the movie, Enter 'b' to show the movie title, Enter 'c' to find the movies, Enter 'q' to quit the movie :"
movies=[]
def add_movie():
  title= (input("Enter Movie Name :"))
  director= (input("Enter Director Name :"))
  year= (input("Enter released year of the movie :"))
  movies.append({
      'title': title,
      'director': director,
      'year': year
  })
def show_the_movies():
    for movie in movies:
        print_movie(movie)
def print_movie(movie):
    print(f"title:{movie['title']}")
    print(f"director:{movie['director']}")
    print(f"year:{movie['year']}")
def find_the_movies():
    search_title=(input("Enter the Movie name you're looking for :"))
    for movie in movies:
        if movie["title"]==search_title:
            print_movie(movie)
def menu():
    selection=(input("MENU_PROMPT"))
    while selection != 'q':
        if selection == "a":
            add_movie()
        elif selection == "b":
            show_the_movies()
        elif selection == "c":
            find_the_movies()
        else:
            print("The given value is error. So please try again!")
        selection = input(MENU_PROMPT)
menu()
# Out:
# MENU_PROMPT a
# Enter Movie Name : Kaavalan
# Enter Director Name : Siddiq
# Enter released year of the movie : 2011
#
#  Enter 'a' to add the movie, Enter 'b' to show the movie title, Enter 'c' to find the movies, Enter 'q' to quit the movie : b
# title:Kaavalan
# director:Siddiq
# year:2011
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_33/4156625040.py in <module>
#      34             print("The given value is error. So please try again!")
#      35         selection = input(MENU_PROMPT)
# ---> 36 menu()
#
# /tmp/ipykernel_33/4156625040.py in menu()
#      33         else:
#      34             print("The given value is error. So please try again!")
# ---> 35         selection = input(MENU_PROMPT)
#      36 menu()
#
# /opt/conda/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1078             self._parent_ident["shell"],
#    1079             self.get_parent("shell"),
# -> 1080             password=False,
#    1081         )
#    1082
#
# /opt/conda/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1119             except KeyboardInterrupt:
#    1120                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1121                 raise KeyboardInterrupt("Interrupted by user") from None
#    1122             except Exception:
#    1123                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
